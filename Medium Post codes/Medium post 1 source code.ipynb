# %% [markdown]
# Name: Larissa Musaga
#
# Course : INST 414
#
# Section: 0103

# %%
#Importing Necessarying libraries
import pandas as pd
import os
import numpy as np
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_271732\2460952492.py in <module>
#       3 import os
#       4 import numpy as np
# ----> 5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#Reading in data
students_exam_df = pd.read_csv(r"C:\Users\Musaga\Desktop\INST 414\Medium post\student_exam_data.csv")
#students_exam_df.info()
#students_exam_df.head()
# Out:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0     4.370861            81.889703          0
# 1     9.556429            72.165782          1
# 2     7.587945            58.571657          0
# 3     6.387926            88.827701          1
# 4     2.404168            81.083870          0

# %%
#Printing formated table
print(students_exam_df.to_string(index=False))
# Out:
#  Study Hours  Previous Exam Score  Pass/Fail
#     4.370861            81.889703          0
#     9.556429            72.165782          1
#     7.587945            58.571657          0
#     6.387926            88.827701          1
#     2.404168            81.083870          0
#     2.403951            49.757016          0
#     1.522753            94.655631          0
#     8.795585            89.352235          1
#     6.410035            96.987995          1
#     7.372653            83.543171          1
#     1.185260            76.804912          0
#     9.729189            65.094582          1
#     8.491984            95.963709          1
#     2.911052            91.963833          0
#     2.636425            42.713120          0
#     2.650641            41.582018          0
#     3.738180            62.587802          0
#     5.722808            88.633200          1
#     4.887505            99.236568          0
#     3.621062            49.025013          0
# ...

# %%
#rearranging the data in order, removing duplicates and utilizing just distinct data.
#students_exam_df.unique()
#students_exam_df["Study Hours","Previous Exam Score", "Pass/Fail"].unique()
unique_values = students_exam_df.stack().unique()
#print(unique_values)
#print(unique_values.to_string(index=False))
